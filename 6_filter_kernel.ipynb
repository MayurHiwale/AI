# %% [markdown]
# # open cv

# %%
#pip install opencv-python

import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# __Edge Detection__
#
# arix value are specified only: 7/8 for invert 9, -1 for sharp

# %%
#load image in grayscale
image= cv2.imread('car.png', cv2.IMREAD_GRAYSCALE)

#define a custom 3x3 kernel/ filter for feature extraction
kernel = np.array([[0, -1, 0],
                   [-1, 4, -1],
                   [0, -1, 0]])

#apply the kernel using convolution
#hadamerd product: element wise multiplication
filter_image = cv2.filter2D(image, -1, kernel)   #-1: image depth(color channels, [3]3color channels)


#display the original and filtered images
plt.figure(figsize=(10, 5))  #width,height inch

#original image
plt.subplot(1, 2, 1) #(1:row, 2:col, 1st)
plt.imshow(image, cmap='gray') #color-map
plt.title('Original Image')
plt.axis('off')  #axis (singular) & axes(plural)

#filtered image
plt.subplot(1, 2, 2) #(1:row, 2:col, 2nd)
plt.imshow(filter_image, cmap='gray') #color-map
plt.title('Filtered Image')
plt.axis('off')  #axis (singular) & axes(plural)

plt.show()

# %% [markdown]
# __Shapning image__

# %%
#load image in grayscale
image= cv2.imread('car.png', cv2.IMREAD_GRAYSCALE)

#define a custom 3x3 kernel/ filter for feature extraction
kernel = np.array([[-1, -1, -1],
                   [-1, 9, -1],
                   [-1, -1, -1]])

#apply the kernel using convolution
#hadamerd product: element wise multiplication
filter_image = cv2.filter2D(image, -1, kernel)   #-1: image depth(color channels, [3]3color channels)


#display the original and filtered images
plt.figure(figsize=(10, 5))  #width,height inch

#original image
plt.subplot(1, 2, 1) #(1:row, 2:col, 1st)
plt.imshow(image, cmap='gray') #color-map
plt.title('Original Image')
plt.axis('off')  #axis (singular) & axes(plural)

#filtered image
plt.subplot(1, 2, 2) #(1:row, 2:col, 2nd)
plt.imshow(filter_image, cmap='gray') #color-map
plt.title('Filtered Image')
plt.axis('off')  #axis (singular) & axes(plural)

plt.show()

# %%
#load image in grayscale
image= cv2.imread('car.png', cv2.IMREAD_GRAYSCALE)

#define a custom 3x3 kernel/ filter for feature extraction
kernel = np.array([[-1, -1, -1],
                   [-1, 9, -1],
                   [-1, -1, -1]])

#apply the kernel using convolution
#hadamerd product: element wise multiplication
filter_image = cv2.filter2D(image, -1, kernel)   #-1: image depth(color channels, [3]3color channels)


#display the original and filtered images
plt.figure(figsize=(10, 5))  #width,height inch

#original image
plt.subplot(1, 2, 1) #(1:row, 2:col, 1st)
plt.imshow(image, cmap='gray') #color-map
plt.title('Original Image')
plt.axis('off')  #axis (singular) & axes(plural)

#filtered image
plt.subplot(1, 2, 2) #(1:row, 2:col, 2nd)
plt.imshow(filter_image, cmap='gray') #color-map
plt.title('Filtered Image')
plt.axis('off')  #axis (singular) & axes(plural)

plt.show()

# %%
#load image in grayscale
image= cv2.imread('IMG_6642.jpg', cv2.IMREAD_GRAYSCALE)

#define a custom 3x3 kernel/ filter for feature extraction
kernel = np.array([[-1, -1, -1],
                   [-1, 9, -1],
                   [-1, -1, -1]])

#apply the kernel using convolution
#hadamerd product: element wise multiplication
filter_image = cv2.filter2D(image, -1, kernel)   #-1: image depth(color channels, [3]3color channels)


#display the original and filtered images
plt.figure(figsize=(10, 5))  #width,height inch

#original image
plt.subplot(1, 2, 1) #(1:row, 2:col, 1st)
plt.imshow(image) #color-map
plt.title('Original Image')
plt.axis('off')  #axis (singular) & axes(plural)

#filtered image
plt.subplot(1, 2, 2) #(1:row, 2:col, 2nd)
plt.imshow(filter_image, cmap='gray') #color-map
plt.title('Filtered Image')
plt.axis('off')  #axis (singular) & axes(plural)

plt.show()
